# %%
import pandas as pd
import numpy as np

# %%
mylist=[5.4,6.1,3,45]
myarray = np.array(mylist)
print(mylist)
print(myarray)
# Out:
# [5.4, 6.1, 3, 45]
# [ 5.4  6.1  3.  45. ]

# %%
myseries1=pd.Series(data=mylist)
print(myseries1)
myseries2=pd.Series(data=myarray)
print(myseries2)
# Out:
# 0     5.4
# 1     6.1
# 2     3.0
# 3    45.0
# 4    64.0
# 5     5.0
# dtype: float64
# 0     5.4
# 1     6.1
# 2     3.0
# 3    45.0
# 4    64.0
# 5     5.0
# dtype: float64

# %%
print(myseries1[2])
# Out:
# 3.0

# %%
mylabels = ['first','second','third','fourth']
myseries3=pd.Series(data=mylist,index=mylabels)
print(myseries3)
# Out:
# first      5.4
# second     6.1
# third      3.0
# fourth    45.0
# dtype: float64

# %%
myseries4=pd.Series(mylist,mylabels)
print(myseries4)
# Out:
# first      5.4
# second     6.1
# third      3.0
# fourth    45.0
# dtype: float64

# %%
print(myseries4['second'])
# Out:
# 6.1

# %%
myseries5=pd.Series([5.5,1.1,8.8,1.6],['first','third','fourth','fifth'])
print(myseries5)
print('')
print(myseries5+myseries4)
# Out:
# first     5.5
# third     1.1
# fourth    8.8
# fifth     1.6
# dtype: float64
#
# fifth      NaN
# first     10.9
# fourth    53.8
# second     NaN
# third      4.1
# dtype: float64

# %%
df1=pd.concat([myseries4,myseries5],axis=1,sort=False)
df1
# Out:
#            0    1
# first    5.4  5.5
# second   6.1  NaN
# third    3.0  1.1
# fourth  45.0  8.8
# fifth    NaN  1.6

# %%
df2=pd.DataFrame(np.random.randn(5,5))
df2
# Out:
#           0         1         2         3         4
# 0  0.307110  0.480594  0.165378 -0.786127  1.346591
# 1  0.927926  0.958453 -0.555037 -1.171754  0.205202
# 2  0.537846 -0.183799 -0.449449  0.257139  1.693648
# 3 -0.070227 -1.096278 -0.384180 -1.777647 -0.191923
# 4  0.189418 -1.124903 -1.302353  1.861927 -1.782276

# %%
df3=pd.DataFrame(np.random.rand(5,5),index=['first row','second row','third row','fourth row','fifth row'],
                columns=['first col','second col','third col','fourth col','fifth col'])
df3
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row    0.933819    0.192400   0.403643    0.490940   0.667385
# second row   0.715144    0.055453   0.971595    0.674162   0.737092
# third row    0.475849    0.990552   0.559254    0.248980   0.510277
# fourth row   0.711515    0.148581   0.629649    0.529998   0.964969
# fifth row    0.641949    0.758628   0.043213    0.361916   0.684555

# %%
print(df3['second col'])
df3[['third col','first col']]
# Out:
# first row     0.192400
# second row    0.055453
# third row     0.990552
# fourth row    0.148581
# fifth row     0.758628
# Name: second col, dtype: float64
#             third col  first col
# first row    0.403643   0.933819
# second row   0.971595   0.715144
# third row    0.559254   0.475849
# fourth row   0.629649   0.711515
# fifth row    0.043213   0.641949

# %%
df3.loc['fourth row']
# Out:
# first col     0.711515
# second col    0.148581
# third col     0.629649
# fourth col    0.529998
# fifth col     0.964969
# Name: fourth row, dtype: float64

# %%
df3.iloc[3]
# Out:
# first col     0.711515
# second col    0.148581
# third col     0.629649
# fourth col    0.529998
# fifth col     0.964969
# Name: fourth row, dtype: float64

# %%
df3.loc[['fourth row','first row'],['second col','first col']]
# Out:
#             second col  first col
# fourth row    0.148581   0.711515
# first row     0.192400   0.933819

# %%
df3>0
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row        True        True       True        True       True
# second row       True        True       True        True       True
# third row        True        True       True        True       True
# fourth row       True        True       True        True       True
# fifth row        True        True       True        True       True

# %%
print (df3[df3>0])
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row    0.933819    0.192400   0.403643    0.490940   0.667385
# second row   0.715144    0.055453   0.971595    0.674162   0.737092
# third row    0.475849    0.990552   0.559254    0.248980   0.510277
# fourth row   0.711515    0.148581   0.629649    0.529998   0.964969
# fifth row    0.641949    0.758628   0.043213    0.361916   0.684555

# %%
df3['sixth col']=np.random.randn(5,1)
df3
# Out:
#             first col  second col  third col  fourth col  fifth col  sixth col
# first row    0.933819    0.192400   0.403643    0.490940   0.667385   1.170804
# second row   0.715144    0.055453   0.971595    0.674162   0.737092   1.996470
# third row    0.475849    0.990552   0.559254    0.248980   0.510277  -0.285477
# fourth row   0.711515    0.148581   0.629649    0.529998   0.964969   1.674173
# fifth row    0.641949    0.758628   0.043213    0.361916   0.684555   0.253475

# %%
df3.drop('first col',axis=1)
# Out:
#             second col  third col  fourth col  fifth col  sixth col
# first row     0.192400   0.403643    0.490940   0.667385   1.170804
# second row    0.055453   0.971595    0.674162   0.737092   1.996470
# third row     0.990552   0.559254    0.248980   0.510277  -0.285477
# fourth row    0.148581   0.629649    0.529998   0.964969   1.674173
# fifth row     0.758628   0.043213    0.361916   0.684555   0.253475

# %%
df3
# Out:
#             first col  second col  third col  fourth col  fifth col  sixth col
# first row    0.933819    0.192400   0.403643    0.490940   0.667385   1.170804
# second row   0.715144    0.055453   0.971595    0.674162   0.737092   1.996470
# third row    0.475849    0.990552   0.559254    0.248980   0.510277  -0.285477
# fourth row   0.711515    0.148581   0.629649    0.529998   0.964969   1.674173
# fifth row    0.641949    0.758628   0.043213    0.361916   0.684555   0.253475

# %%
df4=df3.drop('first col',axis=1)
df4
# Out:
#             second col  third col  fourth col  fifth col  sixth col
# first row     0.192400   0.403643    0.490940   0.667385   1.170804
# second row    0.055453   0.971595    0.674162   0.737092   1.996470
# third row     0.990552   0.559254    0.248980   0.510277  -0.285477
# fourth row    0.148581   0.629649    0.529998   0.964969   1.674173
# fifth row     0.758628   0.043213    0.361916   0.684555   0.253475

# %%
df5=df3.drop('second row',axis=0)
df5
# Out:
#             first col  second col  third col  fourth col  fifth col  sixth col
# first row    0.933819    0.192400   0.403643    0.490940   0.667385   1.170804
# third row    0.475849    0.990552   0.559254    0.248980   0.510277  -0.285477
# fourth row   0.711515    0.148581   0.629649    0.529998   0.964969   1.674173
# fifth row    0.641949    0.758628   0.043213    0.361916   0.684555   0.253475

# %%
df5.reset_index()
# Out:
#         index  first col  second col  third col  fourth col  fifth col  \
# 0   first row   0.933819    0.192400   0.403643    0.490940   0.667385
# 1   third row   0.475849    0.990552   0.559254    0.248980   0.510277
# 2  fourth row   0.711515    0.148581   0.629649    0.529998   0.964969
# 3   fifth row   0.641949    0.758628   0.043213    0.361916   0.684555
#
#    sixth col
# 0   1.170804
# 1  -0.285477
# 2   1.674173
# 3   0.253475

# %%
df5
# Out:
#             first col  second col  third col  fourth col  fifth col  sixth col
# first row    0.933819    0.192400   0.403643    0.490940   0.667385   1.170804
# third row    0.475849    0.990552   0.559254    0.248980   0.510277  -0.285477
# fourth row   0.711515    0.148581   0.629649    0.529998   0.964969   1.674173
# fifth row    0.641949    0.758628   0.043213    0.361916   0.684555   0.253475

# %%
df5.reset_index(inplace=True)
df5
# Out:
#    level_0       index  first col  second col  third col  fourth col  \
# 0        0   first row   0.933819    0.192400   0.403643    0.490940
# 1        1   third row   0.475849    0.990552   0.559254    0.248980
# 2        2  fourth row   0.711515    0.148581   0.629649    0.529998
# 3        3   fifth row   0.641949    0.758628   0.043213    0.361916
#
#    fifth col  sixth col
# 0   0.667385   1.170804
# 1   0.510277  -0.285477
# 2   0.964969   1.674173
# 3   0.684555   0.253475

# %%
df5['new name'] = ['This','is','the','row']
df5
# Out:
#    level_0       index  first col  second col  third col  fourth col  \
# 0        0   first row   0.933819    0.192400   0.403643    0.490940
# 1        1   third row   0.475849    0.990552   0.559254    0.248980
# 2        2  fourth row   0.711515    0.148581   0.629649    0.529998
# 3        3   fifth row   0.641949    0.758628   0.043213    0.361916
#
#    fifth col  sixth col new name
# 0   0.667385   1.170804     This
# 1   0.510277  -0.285477       is
# 2   0.964969   1.674173      the
# 3   0.684555   0.253475      row

# %%
df5.set_index('new name',inplace=True)
df5
# Out:
#           level_0       index  first col  second col  third col  fourth col  \
# new name
# This            0   first row   0.933819    0.192400   0.403643    0.490940
# is              1   third row   0.475849    0.990552   0.559254    0.248980
# the             2  fourth row   0.711515    0.148581   0.629649    0.529998
# row             3   fifth row   0.641949    0.758628   0.043213    0.361916
#
#           fifth col  sixth col
# new name
# This       0.667385   1.170804
# is         0.510277  -0.285477
# the        0.964969   1.674173
# row        0.684555   0.253475

# %%
df5.mean()
# Out:
# level_0       1.500000
# first col     0.690783
# second col    0.522540
# third col     0.408940
# fourth col    0.407958
# fifth col     0.706797
# sixth col     0.703244
# dtype: float64

# %%
df7=pd.DataFrame({"customer":['101','102','103','104'],
                 'cateogry': ['cat2','cat3','cat4','cat5'],
                 'important':['yes','yes','no','no'],
                 'sales': [123,343,3432,112]},index=[0,1,2,3])

df8=pd.DataFrame({"customer":['101','102','103','105'],
                 'color': ['red','yellow','orange','green'],
                 'distance':[21,34,53,21],
                 'sales': [23,343,342,112]},index=[4,5,6,7])

# %%
pd.concat([df7,df8],axis=0,sort=False)
# Out:
#   customer cateogry important  sales   color  distance
# 0      101     cat2       yes    123     NaN       NaN
# 1      102     cat3       yes    343     NaN       NaN
# 2      103     cat4        no   3432     NaN       NaN
# 3      104     cat5        no    112     NaN       NaN
# 4      101      NaN       NaN     23     red      21.0
# 5      102      NaN       NaN    343  yellow      34.0
# 6      103      NaN       NaN    342  orange      53.0
# 7      105      NaN       NaN    112   green      21.0

# %%
pd.concat([df7,df8],axis=0,sort=True)
# Out:
#   cateogry   color customer  distance important  sales
# 0     cat2     NaN      101       NaN       yes    123
# 1     cat3     NaN      102       NaN       yes    343
# 2     cat4     NaN      103       NaN        no   3432
# 3     cat5     NaN      104       NaN        no    112
# 4      NaN     red      101      21.0       NaN     23
# 5      NaN  yellow      102      34.0       NaN    343
# 6      NaN  orange      103      53.0       NaN    342
# 7      NaN   green      105      21.0       NaN    112

# %%
pd.concat([df7,df8],axis=1,sort=False)
# Out:
#   customer cateogry important   sales customer   color  distance  sales
# 0      101     cat2       yes   123.0      NaN     NaN       NaN    NaN
# 1      102     cat3       yes   343.0      NaN     NaN       NaN    NaN
# 2      103     cat4        no  3432.0      NaN     NaN       NaN    NaN
# 3      104     cat5        no   112.0      NaN     NaN       NaN    NaN
# 4      NaN      NaN       NaN     NaN      101     red      21.0   23.0
# 5      NaN      NaN       NaN     NaN      102  yellow      34.0  343.0
# 6      NaN      NaN       NaN     NaN      103  orange      53.0  342.0
# 7      NaN      NaN       NaN     NaN      105   green      21.0  112.0

# %%
pd.merge(df7,df8,how='outer',on='customer')
# Out:
#   customer cateogry important  sales_x   color  distance  sales_y
# 0      101     cat2       yes    123.0     red      21.0     23.0
# 1      102     cat3       yes    343.0  yellow      34.0    343.0
# 2      103     cat4        no   3432.0  orange      53.0    342.0
# 3      104     cat5        no    112.0     NaN       NaN      NaN
# 4      105      NaN       NaN      NaN   green      21.0    112.0

# %%
pd.merge(df7,df8,how='inner',on='customer')
# Out:
#   customer cateogry important  sales_x   color  distance  sales_y
# 0      101     cat2       yes      123     red        21       23
# 1      102     cat3       yes      343  yellow        34      343
# 2      103     cat4        no     3432  orange        53      342

# %%
pd.merge(df7,df8,how='left',on='customer')
# Out:
#   customer cateogry important  sales_x   color  distance  sales_y
# 0      101     cat2       yes      123     red      21.0     23.0
# 1      102     cat3       yes      343  yellow      34.0    343.0
# 2      103     cat4        no     3432  orange      53.0    342.0
# 3      104     cat5        no      112     NaN       NaN      NaN

# %%
pd.merge(df7,df8,how='right',on='customer')
# Out:
#   customer cateogry important  sales_x   color  distance  sales_y
# 0      101     cat2       yes    123.0     red        21       23
# 1      102     cat3       yes    343.0  yellow        34      343
# 2      103     cat4        no   3432.0  orange        53      342
# 3      105      NaN       NaN      NaN   green        21      112

# %%
df9=pd.DataFrame({'Q1':[101,102,103],
                 'Q2':[201,202,203]},
                 index=['I0','I1','I2'])
df10=pd.DataFrame({'Q3':[301,302,303],
                 'Q4':[401,402,403]},
                 index=['I0','I2','I3'])

# %%
df9.join(df10,how='outer')
# Out:
#        Q1     Q2     Q3     Q4
# I0  101.0  201.0  301.0  401.0
# I1  102.0  202.0    NaN    NaN
# I2  103.0  203.0  302.0  402.0
# I3    NaN    NaN  303.0  403.0

# %%
df8['color'].unique()
# Out:
# array(['red', 'yellow', 'orange', 'green'], dtype=object)

# %%
df8['color'].value_counts()
# Out:
# yellow    1
# red       1
# green     1
# orange    1
# Name: color, dtype: int64

# %%
df9.mean()
# Out:
# Q1    102.0
# Q2    202.0
# dtype: float64

# %%
df8.columns
# Out:
# Index(['customer', 'color', 'distance', 'sales'], dtype='object')

# %%
new_df= df8[(df8['customer']!='105') & (df8['color']!='red')]
new_df
# Out:
#   customer   color  distance  sales
# 5      102  yellow        34    343
# 6      103  orange        53    342

# %%
print(df8['sales'].mean())
print(df8['distance'].min())
# Out:
# 205.0
# 21

# %%
def profit(s):
    return s*0.5

# %%
df8['sales'].apply(profit)
# Out:
# 4     11.5
# 5    171.5
# 6    171.0
# 7     56.0
# Name: sales, dtype: float64

# %%
df8['color'].apply(len)
# Out:
# 4    3
# 5    6
# 6    6
# 7    5
# Name: color, dtype: int64

# %%
df11=df8[['distance','sales']]
df11.applymap(profit)
# Out:
#    distance  sales
# 4      10.5   11.5
# 5      17.0  171.5
# 6      26.5  171.0
# 7      10.5   56.0

# %%
def col_sum(co):
    return sum(co)
df11.apply(col_sum)
# Out:
# distance    129
# sales       820
# dtype: int64

# %%
df11.applymap(col_sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-e7bcaa3ec13d> in <module>
# ----> 1 df11.applymap(col_sum)
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py in applymap(self, func)
#    7600             return lib.map_infer(x.astype(object)._values, func)
#    7601
# -> 7602         return self.apply(infer)
#    7603
#    7604     # ----------------------------------------------------------------------
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7543             kwds=kwds,
#    7544         )
# -> 7545         return op.get_result()
#    7546
#    7547     def applymap(self, func) -> "DataFrame":
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/apply.py in apply_standard(self)
#     253
#     254     def apply_standard(self):
# --> 255         results, res_index = self.apply_series_generator()
#     256
#     257         # wrap results
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     282                 for i, v in enumerate(series_gen):
#     283                     # ignore SettingWithCopy here in case the user mutates
# --> 284                     results[i] = self.f(v)
#     285                     if isinstance(results[i], ABCSeries):
#     286                         # If we have a view on v, we need to make a copy because
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py in infer(x)
#    7598             if x.empty:
#    7599                 return lib.map_infer(x, func)
# -> 7600             return lib.map_infer(x.astype(object)._values, func)
#    7601
#    7602         return self.apply(infer)
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-107-500a10881629> in col_sum(co)
#       1 def col_sum(co):
# ----> 2     return sum(co)
#       3 df11.apply(col_sum)
#       4
#
# TypeError: 'int' object is not iterable

# %%
df8
# Out:
#   customer   color  distance  sales
# 4      101     red        21     23
# 5      102  yellow        34    343
# 6      103  orange        53    342
# 7      105   green        21    112

# %%
del df8['color']

# %%
df8
df8.index
# Out:
# Int64Index([4, 5, 6, 7], dtype='int64')

# %%
df8.sort_values(by='distance')
# Out:
#   customer  distance  sales
# 4      101        21     23
# 7      105        21    112
# 5      102        34    343
# 6      103        53    342

# %%
mydict={"customer":['Customer1','Customer1','Customer2','Customer2','Customer3','Customer3'],
                 'product1': [1,2,3.3,43,2,1],
                 'product2':[4,2,32,12,12,1]}
df6=pd.DataFrame(mydict,index=['Purchase1','Purchase2','Purchase3','Purchase4','Purchase5','Purchase6'])
df6
# Out:
#             customer  product1  product2
# Purchase1  Customer1       1.0         4
# Purchase2  Customer1       2.0         2
# Purchase3  Customer2       3.3        32
# Purchase4  Customer2      43.0        12
# Purchase5  Customer3       2.0        12
# Purchase6  Customer3       1.0         1

# %%
grouped_data=df6.groupby('customer')
print(grouped_data)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x1215cd8d0>

# %%
grouped_data.describe()
# Out:
#           product1                                                      \
#              count   mean        std  min     25%    50%     75%   max
# customer
# Customer1      2.0   1.50   0.707107  1.0   1.250   1.50   1.750   2.0
# Customer2      2.0  23.15  28.072139  3.3  13.225  23.15  33.075  43.0
# Customer3      2.0   1.50   0.707107  1.0   1.250   1.50   1.750   2.0
#
#           product2
#              count  mean        std   min    25%   50%    75%   max
# customer
# Customer1      2.0   3.0   1.414214   2.0   2.50   3.0   3.50   4.0
# Customer2      2.0  22.0  14.142136  12.0  17.00  22.0  27.00  32.0
# Customer3      2.0   6.5   7.778175   1.0   3.75   6.5   9.25  12.0

# %%
grouped_data.mean()
# Out:
#            product1  product2
# customer
# Customer1      1.50       3.0
# Customer2     23.15      22.0
# Customer3      1.50       6.5

# %%
df8
# Out:
#   customer  distance  sales
# 4      101        21     23
# 5      102        34    343
# 6      103        53    342
# 7      105        21    112

# %%
df8.to_csv('df8.csv',index=True)

# %%
new_df8=pd.read_csv('df8.csv',index_col=0)
new_df8
# Out:
#    customer  distance  sales
# 4       101        21     23
# 5       102        34    343
# 6       103        53    342
# 7       105        21    112

# %%
df8.to_excel('df8.xlsx',index=False,sheet_name='First Sheet')
newer_df8=pd.read_excel('df8.xlsx',sheet_name='First Sheet')
newer_df8
# Out:
#    customer  distance  sales
# 0       101        21     23
# 1       102        34    343
# 2       103        53    342
# 3       105        21    112

# %%
car_data=pd.read_csv('mtcars.csv')
car_data
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
car_data.shape
# Out:
# (32, 12)

# %%
car_data.columns
# Out:
# Index(['name', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
car_data[['name','mpg']]
# Out:
#                    name   mpg
# 0             Mazda RX4  21.0
# 1         Mazda RX4 Wag  21.0
# 2            Datsun 710  22.8
# 3        Hornet 4 Drive  21.4
# 4     Hornet Sportabout  18.7
# 5               Valiant  18.1
# 6            Duster 360  14.3
# 7             Merc 240D  24.4
# 8              Merc 230  22.8
# 9              Merc 280  19.2
# 10            Merc 280C  17.8
# 11           Merc 450SE  16.4
# 12           Merc 450SL  17.3
# 13          Merc 450SLC  15.2
# 14   Cadillac Fleetwood  10.4
# 15  Lincoln Continental  10.4
# 16    Chrysler Imperial  14.7
# 17             Fiat 128  32.4
# 18          Honda Civic  30.4
# 19       Toyota Corolla  33.9
# 20        Toyota Corona  21.5
# 21     Dodge Challenger  15.5
# 22          AMC Javelin  15.2
# 23           Camaro Z28  13.3
# 24     Pontiac Firebird  19.2
# 25            Fiat X1-9  27.3
# 26        Porsche 914-2  26.0
# 27         Lotus Europa  30.4
# 28       Ford Pantera L  15.8
# 29         Ferrari Dino  19.7
# 30        Maserati Bora  15.0
# 31           Volvo 142E  21.4

# %%
car_data['name'].loc[2:4]
# Out:
# 2           Datsun 710
# 3       Hornet 4 Drive
# 4    Hornet Sportabout
# Name: name, dtype: object

# %%
car_data.set_index('name')
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# name
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#                      carb
# name
# Mazda RX4               4
# Mazda RX4 Wag           4
# Datsun 710              1
# Hornet 4 Drive          1
# Hornet Sportabout       2
# Valiant                 1
# Duster 360              4
# Merc 240D               2
# Merc 230                2
# Merc 280                4
# Merc 280C               4
# Merc 450SE              3
# Merc 450SL              3
# Merc 450SLC             3
# Cadillac Fleetwood      4
# Lincoln Continental     4
# Chrysler Imperial       4
# Fiat 128                1
# Honda Civic             2
# Toyota Corolla          1
# Toyota Corona           1
# Dodge Challenger        2
# AMC Javelin             2
# Camaro Z28              4
# Pontiac Firebird        2
# Fiat X1-9               1
# Porsche 914-2           2
# Lotus Europa            2
# Ford Pantera L          4
# Ferrari Dino            6
# Maserati Bora           8
# Volvo 142E              2

# %%
car_data.reset_index(inplace=True,drop=True)

# %%
car_data['mpg'].mean()
# Out:
# 20.090625000000003

# %%
car_data
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
options = ['Fiat 128','Volvo 142E']
car_data1=car_data[car_data['name'].isin(options)]

# %%
car_data1[['cyl','disp']]
# Out:
#     cyl   disp
# 17    4   78.7
# 31    4  121.0
